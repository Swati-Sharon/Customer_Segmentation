# %% [markdown]
# #1. Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Loading Data**

# %%
t=pd.read_excel('Dataset.xlsx',sheet_name='Transaction')

# %% [markdown]
# #2. Data Quality Analysis

# %% [markdown]
# 2.1 Checking records

# %%
t.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %% [markdown]
# 2.2. Check information of columns and their datatypes

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %% [markdown]
# # 3. Handling Missing Values

# %%
#returns the number of missing values in the dataset
t.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
# Find percentage of missing values in each column of a #pandas dataframe
t.isnull().mean()*100
# Out:
# transaction_id             0.000
# product_id                 0.000
# customer_id                0.000
# transaction_date           0.000
# online_order               1.800
# order_status               0.000
# brand                      0.985
# product_line               0.985
# product_class              0.985
# product_size               0.985
# list_price                 0.000
# standard_cost              0.985
# product_first_sold_date    0.985
# dtype: float64

# %% [markdown]
# **online_order,brand,product_line,product_class,product_size,standard_cost,product_first_sold_date have missing values**

# %% [markdown]
# 5.1 Online_Order

# %% [markdown]
# 6. Check what are the possible values for online_order

# %%
#online_order that are null
t[t['online_order'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 97                 98          49          333       2017-06-23           NaN
# 166               167          90         3177       2017-04-26           NaN
# 169               170           6          404       2017-10-16           NaN
# 250               251          63         1967       2017-04-11           NaN
# 300               301          78         2530       2017-03-24           NaN
# ...               ...         ...          ...              ...           ...
# 19514           19515          51          690       2017-01-22           NaN
# 19573           19574          18         1735       2017-01-15           NaN
# 19580           19581          49         1933       2017-10-12           NaN
# 19635           19636          98         1389       2017-07-26           NaN
# 19843           19844           3            8       2017-01-28           NaN
#
# ...

# %%
#count of null values in online_order before
t['online_order'].isnull().sum()
# Out:
# 360

# %%
t['online_order'].mode()
# Out:
# 0    1.0
# Name: online_order, dtype: float64

# %%
t['online_order'].value_counts()
# Out:
# online_order
# 1.0    9829
# 0.0    9811
# Name: count, dtype: int64

# %%
#Since count of 1 is more we imputate it in NaN
t['online_order'].fillna(1,inplace=True)

# %%
#count of null values in column online-order is zero
t['online_order'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 5.2 Brand

# %%
#number of brand values which is null
t['brand'].isnull().sum()
# Out:
# 197

# %%
#checking other columns corresponding to brand which is null so that we can know the pattern
t[t['brand'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 136               137           0          431       2017-09-23           0.0
# 159               160           0         3300       2017-08-27           0.0
# 366               367           0         1614       2017-03-10           0.0
# 406               407           0         2559       2017-06-14           1.0
# 676               677           0         2609       2017-07-02           0.0
# ...               ...         ...          ...              ...           ...
# 19340           19341           0          443       2017-12-26           1.0
# 19383           19384           0         2407       2017-06-11           0.0
# 19793           19794           0         2860       2017-01-13           0.0
# 19859           19860           0         2468       2017-06-24           1.0
# 19871           19872           0           61       2017-03-17           1.0
#
# ...

# %%
#checking brand wrt the other column of concern we see that if brand is Nan others are also nan.
t[t['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size','standard_cost', 'product_first_sold_date']]
#t[t['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size','standard_cost', 'product_first_sold_date']].shape[0]
# Out:
#       brand product_line product_class product_size  standard_cost  \
# 136     NaN          NaN           NaN          NaN            NaN
# 159     NaN          NaN           NaN          NaN            NaN
# 366     NaN          NaN           NaN          NaN            NaN
# 406     NaN          NaN           NaN          NaN            NaN
# 676     NaN          NaN           NaN          NaN            NaN
# ...     ...          ...           ...          ...            ...
# 19340   NaN          NaN           NaN          NaN            NaN
# 19383   NaN          NaN           NaN          NaN            NaN
# 19793   NaN          NaN           NaN          NaN            NaN
# 19859   NaN          NaN           NaN          NaN            NaN
# 19871   NaN          NaN           NaN          NaN            NaN
#
#        product_first_sold_date
# 136                        NaN
# 159                        NaN
# 366                        NaN
# 406                        NaN
# ...

# %%
#to get the index of the values which have NaN as brand inorder to drop it further
a=t[t['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size','standard_cost', 'product_first_sold_date']].index

# %%
t[t['brand'].isnull()][['brand', 'product_line', 'product_class', 'product_size','standard_cost', 'product_first_sold_date']]
# Out:
#       brand product_line product_class product_size  standard_cost  \
# 136     NaN          NaN           NaN          NaN            NaN
# 159     NaN          NaN           NaN          NaN            NaN
# 366     NaN          NaN           NaN          NaN            NaN
# 406     NaN          NaN           NaN          NaN            NaN
# 676     NaN          NaN           NaN          NaN            NaN
# ...     ...          ...           ...          ...            ...
# 19340   NaN          NaN           NaN          NaN            NaN
# 19383   NaN          NaN           NaN          NaN            NaN
# 19793   NaN          NaN           NaN          NaN            NaN
# 19859   NaN          NaN           NaN          NaN            NaN
# 19871   NaN          NaN           NaN          NaN            NaN
#
#        product_first_sold_date
# 136                        NaN
# 159                        NaN
# 366                        NaN
# 406                        NaN
# ...

# %%
t.drop(index=a,axis=0,inplace=True)

# %%
t['brand'].isnull().sum()
# Out:
# 0

# %%
#checking total missing value after cleaning missing values
t.shape[0]
# Out:
# 19803

# %%
t['product_class'].isnull().sum()
# Out:
# 0

# %%
t.isnull().sum()
# Out:
# transaction_id             0
# product_id                 0
# customer_id                0
# transaction_date           0
# online_order               0
# order_status               0
# brand                      0
# product_line               0
# product_class              0
# product_size               0
# list_price                 0
# standard_cost              0
# product_first_sold_date    0
# dtype: int64

# %% [markdown]
# Thus solving Brand we also deal with other missing data thus rectifying all the missing values

# %% [markdown]
# #4. Data Inconsistency

# %% [markdown]
# Data can be inconsistent in non-numeric section so we need to check what are the non-numeric column

# %%
non_numeric = t.select_dtypes(exclude=[np.number])
non_numeric_col = non_numeric.columns.values
non_numeric_col
# Out:
# array(['transaction_date', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size'], dtype=object)

# %%
t['order_status'].value_counts()
# Out:
# order_status
# Approved     19625
# Cancelled      178
# Name: count, dtype: int64

# %%
t['online_order'].value_counts()
# Out:
# online_order
# 1.0    10097
# 0.0     9706
# Name: count, dtype: int64

# %%
t['brand'].value_counts()
# Out:
# brand
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: count, dtype: int64

# %%
t['product_line'].value_counts()
# Out:
# product_line
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64

# %%
t['product_class'].value_counts()
# Out:
# product_class
# medium    13826
# high       3013
# low        2964
# Name: count, dtype: int64

# %%
t['product_size'].value_counts()
# Out:
# product_size
# medium    12990
# large      3976
# small      2837
# Name: count, dtype: int64

# %% [markdown]
# #5. Duplicate

# %%
# Check for duplicate rows based on specific columns
df=pd.DataFrame(t)
duplicate_rows_subset = df.duplicated(subset=['transaction_id'])

# Check if there are any duplicates
if duplicate_rows_subset.any():
    print("There are duplicates based on transaction_id.")
else:
    print("There are no duplicates based on transaction_id.")
# Out:
# There are no duplicates based on transaction_id.

# %% [markdown]
# #6. Export

# %%
t.to_csv('Transaction_cleaned.csv', index=False)
